# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('data/CarPrice_Assignment.csv')

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data['fuelsystem'].value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %% [markdown]
# Saving the copy of the dataset

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data_copy = data.copy()

# %% [markdown]
# Top 5 records of the dataset

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# Last 5 records of the dataset

# %%
data.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %% [markdown]
# Checking the duplicates in the dataset

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Shape of the dataset

# %%
data.shape
# Out:
# (205, 26)

# %% [markdown]
# There are 205 rows and the 26 columns

# %% [markdown]
# Checking the information of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# Changing door number into integer value

# %%
data['doornumber'] = data['doornumber'].map({'two':2,'four':4})

# %%
data['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %% [markdown]
# Changing cylinder number into integer value

# %%
data['cylindernumber'] = data['cylindernumber'].map({'four':4,'six':6,'five':5,'three':3,'twelve':12,'two':2,'eight':8})

# %% [markdown]
# Drop the car ID column from the dataset

# %%
data.drop('car_ID',axis=1,inplace=True)

# %% [markdown]
# Seperating the categorical and the numerical columns

# %%
lst_cat=[]
lst_num=[]
for i in data.columns :
    if (data.dtypes[i]=='O') :
        lst_cat.append(i)
    else :
        lst_num.append(i)

# %%
lst_cat
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'fuelsystem']

# %%
lst_num
# Out:
# ['symboling',
#  'doornumber',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %% [markdown]
# Cheking the oultiers in the numerical column

# %%
def outliers(data,variable) :
    q3 = data[variable].quantile(0.75)
    q1 = data[variable].quantile(0.25)
    iqr = q3-q1
    lower_fence = q1-1.5*iqr
    higher_fence = q3+1.5*iqr

    return lower_fence,higher_fence

# %%
outliers(data,'symboling')
# Out:
# (-3.0, 5.0)

# %% [markdown]
# Seeing the range of the outliers in the numerical columns

# %%
for i in lst_num :
    print("Outliers of the {} columns is {}".format(i,outliers(data,i)))
# Out:
# Outliers of the symboling columns is (-3.0, 5.0)
# Outliers of the doornumber columns is (-1.0, 7.0)
# Outliers of the wheelbase columns is (82.64999999999999, 114.25000000000001)
# Outliers of the carlength columns is (141.10000000000002, 208.29999999999995)
# Outliers of the carwidth columns is (59.89999999999998, 71.10000000000002)
# Outliers of the carheight columns is (46.75, 60.75)
# Outliers of the curbweight columns is (960.0, 4120.0)
# Outliers of the cylindernumber columns is (4.0, 4.0)
# Outliers of the enginesize columns is (31.0, 207.0)
# Outliers of the boreratio columns is (2.505, 4.2250000000000005)
# Outliers of the stroke columns is (2.6599999999999993, 3.8600000000000003)
# Outliers of the compressionratio columns is (7.399999999999999, 10.600000000000001)
# Outliers of the horsepower columns is (1.0, 185.0)
# Outliers of the peakrpm columns is (3750.0, 6550.0)
# Outliers of the citympg columns is (2.5, 46.5)
# Outliers of the highwaympg columns is (11.5, 47.5)
# ...

# %% [markdown]
# Checking the missing values in the dataset

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# There are no missing values in the dataset

# %% [markdown]
# Let's do the analysis with the help of the graph

# %%
lst_num
# Out:
# ['symboling',
#  'doornumber',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
for i in lst_num :
    fig, axes = plt.subplots()
    sns.kdeplot(data=data,x=data[i],ax=axes)
    axes.set_xlim((data[i].min(), data[i].max()))
    ax2 = axes.twinx()
    sns.histplot(data=data, x=data[i], discrete=True, ax=ax2)

# %%
data[data['doornumber']==3]
# Out:
# Empty DataFrame
# Columns: [symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 25 columns]

# %%
data[(data['doornumber']>=3.50) & (data['doornumber']<=4.0)]
# Out:
#      symboling          CarName fueltype aspiration  doornumber carbody  \
# 3            2      audi 100 ls      gas        std           4   sedan
# 4            2       audi 100ls      gas        std           4   sedan
# 6            1       audi 100ls      gas        std           4   sedan
# 7            1        audi 5000      gas        std           4   wagon
# 8            1        audi 4000      gas      turbo           4   sedan
# ..         ...              ...      ...        ...         ...     ...
# 200         -1  volvo 145e (sw)      gas        std           4   sedan
# 201         -1      volvo 144ea      gas      turbo           4   sedan
# 202         -1      volvo 244dl      gas        std           4   sedan
# 203         -1        volvo 246   diesel      turbo           4   sedan
# 204         -1      volvo 264gl      gas      turbo           4   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# ...

# %%
data['enginesize'].value_counts()
# Out:
# enginesize
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 152     6
# 181     6
# 146     6
# 121     6
# 156     5
# 136     5
# 91      5
# 183     4
# 130     4
# 171     3
# 70      3
# 194     3
# 209     3
# 164     3
# 258     2
# 140     2
# 134     2
# 234     2
# 132     2
# 131     2
# 173     1
# 203     1
# 161     1
# 80      1
# 151     1
# 103     1
# 304     1
# 308     1
# 326     1
# 119     1
# 111     1
# 79      1
# 61      1
# 145     1
# Name: count, dtype: int64

# %%
data['CarName'].value_counts()[0:10]
# Out:
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
# mazda 626               3
# toyota mark ii          3
# mitsubishi outlander    3
# mitsubishi g4           3
# honda civic             3
# Name: count, dtype: int64

# %%
car_top_10_name = data['CarName'].value_counts()[0:10].index.to_list()
car_top_10_name_values  = data['CarName'].value_counts()[0:10].values

# %%
fig, ax = plt.subplots()

car_top_10_name
car_top_10_name_values
ax.bar(car_top_10_name, car_top_10_name_values)

ax.set_ylabel('Numebr of car')
ax.set_title('Number of top 10 car on the basis of quantity')
plt.xticks(rotation=90)
plt.show()

# %%
car_name_counts = data['CarName'].value_counts()

# Extract the last 10 unique car names and their counts
car_last_10_name = data['CarName'].value_counts()[-10:].index.to_list()
car_last_10_name_values = data['CarName'].value_counts()[-10:].values

# %%
fig, ax = plt.subplots()

car_last_10_name
car_last_10_name_values
ax.bar(car_last_10_name, car_last_10_name_values)

ax.set_ylabel('Numebr of car')
ax.set_title('Number of last 10 car on the basis of quantity')
plt.xticks(rotation=90)
plt.show()

# %%
fuel_type = data['fueltype'].value_counts().index.to_list()
fuel_type_quantity = data['fueltype'].value_counts().values

# %%
fig, ax = plt.subplots()

fuel_type
fuel_type_quantity

ax.bar(fuel_type, fuel_type_quantity)

ax.set_ylabel('Quantity of the fuel types')
ax.set_title('Fuel type vs quantity of fuel type')
plt.show()

# %%
data['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
data['fuelsystem'].value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
fuel_system_name = data['fuelsystem'].value_counts().index.to_list()

# %%
fuel_system_name
# Out:
# ['mpfi', '2bbl', 'idi', '1bbl', 'spdi', '4bbl', 'mfi', 'spfi']

# %%
fuel_system_quantity =  data['fuelsystem'].value_counts().values

# %%
fuel_system_quantity
# Out:
# array([94, 66, 20, 11,  9,  3,  1,  1], dtype=int64)

# %%
fuel_system_name
fuel_system_quantity
fig, ax = plt.subplots()
ax.bar(fuel_system_name, fuel_system_quantity)

ax.set_ylabel('Numebr of fuel system')
ax.set_title('Number of fuel system vs fuel system quantity')
plt.xticks(rotation=90)
plt.show()

# %%
drivewheel_name = data['drivewheel'].value_counts().index.to_list()
drivewheel_count = data['drivewheel'].value_counts().values
fig, ax = plt.subplots()
ax.pie(drivewheel_count, labels=drivewheel_name, autopct='%1.1f%%')
plt.title('Distribution of the drivewheel')
# Out:
# Text(0.5, 1.0, 'Distribution of the drivewheel')

# %%
data['enginelocation'].value_counts()
# Out:
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64

# %%
engine_name = data['enginelocation'].value_counts().index.to_list()
engine_counts = data['enginelocation'].value_counts().values
fig, ax = plt.subplots()
ax.pie(engine_counts, labels=engine_name, autopct='%1.1f%%')
plt.title('Distribution of the location of engine')
# Out:
# Text(0.5, 1.0, 'Distribution of the location of engine')

# %%
enginetype_name = data['enginetype'].value_counts().index.to_list()
enginetype_counts = data['enginetype'].value_counts().values
fig, ax = plt.subplots()
ax.pie(enginetype_counts, labels=enginetype_name, autopct='%1.1f%%')
plt.title('Distribution of the type of engine')
# Out:
# Text(0.5, 1.0, 'Distribution of the type of engine')

# %%
fuelsystem_name = data['fuelsystem'].value_counts().index.to_list()
fuelsystem_counts = data['fuelsystem'].value_counts().values
fig, ax = plt.subplots()
ax.pie(fuelsystem_counts, labels=fuel_system_name, autopct='%1.1f%%')
plt.title('Distribution of the fuel system')
# Out:
# Text(0.5, 1.0, 'Distribution of the fuel system')

# %%
sns.pairplot(data)

# %%
# plotting correlation heatmap
# Create a correlation heatmap within the specified subplot
fig, ax = plt.subplots(figsize=(10, 8))
dataplot = sns.heatmap(data.corr(numeric_only=True), annot=True, ax=ax)

# Display the heatmap
plt.show()

# %% [markdown]
# Highwaymilage vs Citymilage

# %%
sns.scatterplot(data=data,x=data['highwaympg'],y=data['citympg'])
plt.title('Scatter Plot of the Highway Mileage vs City Mileage')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of the Highway Mileage vs City Mileage')

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [markdown]
# Analysis with the price columns

# %%
lst_plot=['cylindernumber','carlength','carwidth','curbweight','enginesize','horsepower','peakrpm','highwaympg','citympg']
for i in lst_plot :
    sns.scatterplot(data=data,x=data[i],y=data['price'])
    plt.title('Scatter plot of {} vs Price'.format(i))
    plt.show()

# %% [markdown]
# Analysis with the carbweight

# %% [markdown]
# carbweight->The weight of a car without occupants or baggage.

# %%
lst_carbweight = ['citympg', 'highwaympg', 'horsepower','enginesize', 'carwidth','carlength','wheelbase']
for i in lst_plot :
    sns.scatterplot(data=data,x=data[i],y=data['curbweight'])
    plt.title('Scatter plot of {} vs carbweight'.format(i))
    plt.show()

# %% [markdown]
# Analysis with the car length

# %%
lst_carlength=['carwidth','wheelbase']
for i in lst_carlength :
    sns.scatterplot(data=data,x=data[i],y=data['carlength'])
    plt.title('Scatter plot of {} vs Car Length'.format(i))
    plt.show()

# %% [markdown]
# Analysis based on the carwidth

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
lst_carwidth = ['wheelbase','enginesize']
for i in lst_carlength :
    sns.scatterplot(data=data,x=data[i],y=data['carlength'])
    plt.title('Scatter plot of {} vs Wheelbase'.format(i))
    plt.show()

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [markdown]
# Analysis on the Curbweight vs Wheelbase

# %%
sns.scatterplot(data=data,x=data['curbweight'],y=data['wheelbase'])
plt.title('Scatter plot of curbweight vs wheelbase')
plt.show()

# %% [markdown]
# # Saving the clean csv file

# %%
data.to_csv('car_price_clean.csv',index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
# ...
